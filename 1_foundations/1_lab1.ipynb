# %% [markdown]
# # Bienvenido al comienzo de tu aventura en Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">¿Listo para la acción?</h2>
# <span style="color:#ff7800;">¿Has completado todos los pasos de configuración en la carpeta <a href="../setup/">setup</a>?<br/>
#
# ¿Has consultado las guías en la carpeta <a href="../guides/01_intro.ipynb">guides</a>?<br/>
#
# En ese caso, ¡estás listo! </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#00bfff;">Este código es un recurso activo; esté atento a mis actualizaciones</h2>
# <span style="color:#00bfff;">Actualizo periódicamente. A medida que los usuarios hacen preguntas o tienen problemas, añado más ejemplos y mejoro las explicaciones. Por lo tanto, es posible que el código a continuación no sea idéntico al de los vídeos, ya que he añadido más pasos y mejores comentarios. Considérelo como un libro interactivo que acompaña a las clases.<br/><br/>
# Intento enviar correos electrónicos regularmente con actualizaciones importantes relacionadas con el curso. Puedes encontrarlo en la sección "Anuncios" de Udemy, en la barra lateral izquierda. También puedes optar por recibir mis correos electrónicos a través de la configuración de notificaciones en Udemy. Soy respetuoso con tu bandeja de entrada y siempre intento aportar valor con mis correos.
#
# </span>
# </td>
# </tr>
# </table>

# %% [markdown]
# ### Y por favor, recuerda contactarme si puedo ayudarte.
#
# Me encantaría conectar contigo: https://www.linkedin.com/in/juan-gabriel-gomila-salas/
#
# ### ¿Eres nuevo en Notebooks como este? ¡Visita la carpeta de guías!
#
# Para comprobar que ya has añadido las extensiones de Python y Jupyter a Cursor, si aún no las tienes instaladas:
# - Abre Extensiones (Ver >> Extensiones).
# - Busca Python y, cuando aparezcan los resultados, haz clic en la de ms-python e instálala si aún no está instalada.
# - Busca Jupyter y, cuando aparezcan los resultados, haz clic en la de Microsoft e instálala si aún no está instalada.
# Luego, ve a Ver >> Explorador para volver al Explorador de archivos.
#
# Y luego:
# 1. Haz clic donde dice "Seleccionar Kernel" cerca de la esquina superior derecha y selecciona la opción `.venv (Python 3.12.9)` o similar, que debería ser la primera opción o la más destacada. Quizás primero debas seleccionar "Entornos de Python".
# 2. Haz clic en cada celda a continuación, comenzando por la celda inmediatamente inferior a este texto, y presiona Mayús+Intro para ejecutar.
# 3. ¡Disfruta!
#
# Después de hacer clic en "Seleccionar Kernel", si no hay ninguna opción como `.venv (Python 3.12.9)`, haz lo siguiente:
# 1. En Mac: En el menú Cursor, selecciona Configuración >> Configuración de VS Code (NOTA: asegúrate de seleccionar `Configuración de VSCode`, no `Configuración de Cursor`). En una PC con Windows: En el menú Archivo, seleccione Preferencias >> Configuración de VS Code (NOTA: asegúrate de seleccionar "Configuración de VS Code" y no "Configuración de Cursor").
# 2. En la barra de búsqueda de Configuración, escriba "venv".
# 3. En el campo "Ruta a la carpeta con la lista de entornos virtuales", introduzca la ruta a la raíz del proyecto, como C:\Users\username\projects\agents (en una PC con Windows) o /Users/username/projects/agents (en Mac o Linux).
# Inténtelo de nuevo.
#
# ¿Tiene problemas porque faltan versiones de Python en la lista? ¿Ha usado Anaconda anteriormente? Podría estar interfiriendo. Salga de Cursor, abra una nueva línea de comandos y asegúrese de que su entorno de Anaconda esté desactivado: `conda deactivate`
# Si aún tiene problemas con las versiones de Conda y Python, es posible que también deba ejecutar esto: `conda config --set auto_activate_base false`
# Y luego, desde el directorio Agentes, debería poder ejecutar `uv python list` y ver la versión de Python 3.12.

# %%
# Empecemos por hacer un import
from dotenv import load_dotenv

# %%
# A continuación, es el momento de cargar las claves API en las variables de entorno.

load_dotenv(override=True)
# Out:
# True

# %%
# Comprobamos las claves

import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"La clave API de OpenAI existe y empieza por {openai_api_key[:8]}")
else:
    print("La clave API de OpenAI no existe - Dirígete a la guía de solución de problemas en la carpeta de configuración.")
# Out:
# La clave API de OpenAI existe y empieza por sk-proj-

# %%
# Y ahora, la importante declaración de importación
# Si recibes un error de importación, consulta la guía de solución de problemas

from openai import OpenAI

# %%
# Ahora crearemos una instancia de la clase OpenAI.
# Si no estás seguro de lo que significa crear una instancia de una clase, ¡visita la carpeta de guías!
# Si recibes un error de nombre, visita la carpeta de guías para obtener más información sobre los errores de nombre.

openai = OpenAI()

# %%
# Crea una lista de mensajes en el formato familiar de OpenAI

messages = [{"role": "user", "content": "¿Cuanto es 2+2?"}]

# %%
# ¡Y ahora, a llamarlo! Si tienes algún problema, consulta la guía de solución de problemas.
# Usa GPT 4.1 nano, el modelo increíblemente económico.

response = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 es 4.

# %%
# Y ahora, vamos a llamar a la API de OpenAI

question = "Proponga una pregunta difícil y desafiante para evaluar el coeficiente intelectual de alguien. Responde únicamente con la pregunta."
messages = [{"role": "user", "content": question}]

# %%
# Pregúntale: usa GPT 4.1 mini, aún barato pero más potente que nano

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# Si cinco máquinas pueden fabricar cinco artículos en cinco minutos, ¿cuánto tiempo tardarán cien máquinas en fabricar cien artículos?

# %%
# una nueva lista de mensajes
messages = [{"role": "user", "content": question}]

# %%
# Hacemos una nueva pregunta

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Vamos a analizar el problema paso a paso.
#
# **Datos del problema:**
# - 5 máquinas fabrican 5 artículos en 5 minutos.
#
# Queremos saber: **¿Cuánto tiempo tardarán 100 máquinas en fabricar 100 artículos?**
#
# ---
#
# ### Paso 1: Encontrar la tasa de trabajo por máquina
#
# Si 5 máquinas fabrican 5 artículos en 5 minutos, entonces:
#
# - En 5 minutos: 5 máquinas → 5 artículos
# - Por máquina: 1 máquina en 5 minutos → 1 artículo
#
# Esto indica que **cada máquina fabrica 1 artículo en 5 minutos**.
#
# ---
#
# ### Paso 2: Calcular el tiempo para 100 máquinas fabricando 100 artículos
#
# Dado que cada máquina produce 1 artículo en 5 minutos:
#
# - 100 máquinas trabajando al mismo tiempo fabricarán 100 artículos en **5 minutos**.
#
# ---
#
# ### **Respuesta:**
#
# Las 100 máquinas tardarán **5 minutos** en fabricar 100 artículos.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Vamos a analizar el problema paso a paso.
#
# **Datos del problema:**
# - 5 máquinas fabrican 5 artículos en 5 minutos.
#
# Queremos saber: **¿Cuánto tiempo tardarán 100 máquinas en fabricar 100 artículos?**
#
# ---
#
# ### Paso 1: Encontrar la tasa de trabajo por máquina
#
# Si 5 máquinas fabrican 5 artículos en 5 minutos, entonces:
#
# - En 5 minutos: 5 máquinas → 5 artículos
# - Por máquina: 1 máquina en 5 minutos → 1 artículo
#
# Esto indica que **cada máquina fabrica 1 artículo en 5 minutos**.
#
# ---
#
# ### Paso 2: Calcular el tiempo para 100 máquinas fabricando 100 artículos
#
# Dado que cada máquina produce 1 artículo en 5 minutos:
#
# - 100 máquinas trabajando al mismo tiempo fabricarán 100 artículos en **5 minutos**.
#
# ---
#
# ### **Respuesta:**
#
# Las 100 máquinas tardarán **5 minutos** en fabricar 100 artículos.

# %% [markdown]
# # ¡Felicidades!
#
# ¡Ese fue un pequeño y sencillo paso hacia la IA Agentic con tu nuevo entorno!
#
# La próxima vez que las cosas se pongan más interesantes...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
# <tr>
# <td style="width: 150px; height: 150px; vertical-align: middle;">
# <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
# </td>
# <td>
# <h2 style="color:#ff7800;">Ejercicio</h2>
# <span style="color:#ff7800;">Ahora, prueba esta aplicación comercial:<br/>
# Primero, pide al LLM que elija un área de negocio que valga la pena explorar para una oportunidad de IA con Agentic.<br/>
# Después, pide al LLM que presente un problema en esa industria, algo desafiante que pueda ser propicio para una solución con Agentic.<br/>
# Finalmente, pide a la tercera convocatoria del LLM que proponga la solución de IA con Agentic. </span>
# </td>
# </tr>
# </table>

# %%
# Priemro creamos el mensaje
from IPython.display import Markdown, display

messages = [{"role": "user", "content": "Elije un area de negocio que valga la pena explorar para una oportunidad de IA con Agentic."}]

# Hacemos la primera llamada:

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

# Luego leemos la idea de negocio:
business_idea = response.choices[0].message.content
display(Markdown(business_idea))

# Y repetimos!
messages = [{"role": "user", "content": f"Presenta un problema en {business_idea}, algo desafiante que pueda ser propicio para una solución con Agentic."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

question = response.choices[0].message.content
print("="*20)
display(Markdown(question))

# Y ahora, la tercera llamada:
messages = [{"role": "user", "content": f"proporciona una solicion para el problema {question} con Agentic."}]

response = openai.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

solution = response.choices[0].message.content
print("="*20)

display(Markdown(solution))
# Out:
# Una área de negocio que vale mucho la pena explorar para una oportunidad de IA con enfoque agentic (es decir, agentes de IA con autonomía para tomar decisiones y actuar de forma proactiva) es **la gestión inteligente de la cadena de suministro y logística**.
#
# ### ¿Por qué la gestión de la cadena de suministro?
#
# 1. **Complejidad y dinámica**: Las cadenas de suministro modernas son muy complejas, con múltiples actores, proveedores, incertidumbres en la demanda y restricciones logísticas. La IA agentic puede actuar autónomamente para anticipar problemas, optimizar rutas, gestionar inventarios y negociar con proveedores.
#
# 2. **Impacto económico alto**: Mejorar la eficiencia y reducir costos en la cadena de suministro tiene un impacto directo en la rentabilidad de empresas de casi todos los sectores (manufactura, retail, alimentación, farmacéutica, etc.).
#
# 3. **Capacidad de acción autónoma**: Los agentes de IA pueden monitorear continuamente datos en tiempo real, detectar anomalías, prever interrupciones (como retrasos o escasez de materiales) y tomar medidas correctivas sin necesidad de intervención humana constante.
#
# 4. **Integración con otras tecnologías**: IA agentic puede integrarse con IoT (sensores en almacenes o flotas de transporte), sistemas ERP y plataformas de comercio electrónico para crear una solución integrada, proactiva y altamente eficiente.
#
# ### Ejemplos concretos de aplicaciones:
#
# - Un agente IA que gestione automáticamente la programación de entregas optimizando rutas y tiempos, negociando con proveedores y transportistas en tiempo real.
# - Un sistema que prediga demandas con alta precisión y ajuste automáticamente niveles de inventario para minimizar costos de almacenamiento y evitar rupturas de stock.
# - Agentes capaces de coordinar la gestión de múltiples almacenes y centros de distribución asegurando que el flujo logístico sea fluido y reactivo ante cualquier eventualidad.
#
# ---
#
# En resumen, la **gestión inteligente y autónoma de la cadena de suministro y logística** es un área con gran potencial para aplicar IA agentic, dado que permite obtener ahorros significativos, mejora la resiliencia operativa y aporta una gran ventaja competitiva a las empresas. ¿Quieres que te ayude a identificar casos específicos dentro de esta área o cómo empezar a diseñar una solución agentic para ella?
# ====================
# Claro, aquí tienes un problema específico y desafiante dentro de la gestión inteligente de la cadena de suministro que es ideal para una solución con IA agentic:
#
# ---
#
# ### Problema: **Gestión autónoma y proactiva de interrupciones en la cadena de suministro global**
#
# #### Descripción del problema
#
# Las cadenas de suministro globales se enfrentan constantemente a interrupciones inesperadas: desastres naturales, huelgas, retrasos en aduanas, bloqueos logísticos, cambios regulatorios o incluso fluctuaciones repentinas en la demanda. Estas interrupciones suelen detectarse demasiado tarde o la respuesta es demasiado burocrática y lenta, lo que genera:
#
# - Desabastecimiento en puntos clave.
# - Costos elevados por envíos de emergencia o almacenamiento excesivo.
# - Pérdida de ventas y clientes por falta de disponibilidad.
# - Dificultad para reconfigurar rutas o fuentes de suministro a tiempo.
#
# El reto es enorme porque la cadena involucra múltiples actores, contratos, regulaciones, condiciones geopolíticas y un volumen gigantesco de datos cambiantes en tiempo real.
#
# #### ¿Por qué es ideal para IA agentic?
#
# Un agente de IA con autonomía proactiva puede:
#
# - Monitorizar continuamente múltiples fuentes de datos (noticias, sensores IoT, datos de tráfico, clima, inventarios, permisos aduaneros).
# - Detectar patrones de riesgo o anomalías que indiquen posibles interrupciones inminentes.
# - Evaluar automáticamente el impacto probable en el flujo logístico, costo y tiempos.
# - Negociar alternativas y ejecutar modificaciones en la cadena de suministro (cambiar proveedores, alterar rutas, ajustar inventarios) sin intervención humana o con mínima supervisión.
# - Aprender y adaptar decisiones conforme evolucionan las circunstancias y pone en práctica acciones preventivas de forma anticipada.
#
# #### Desafíos a resolver
#
# 1. **Integración y análisis multimodal**: combinar datos heterogéneos y en tiempo real con fuentes externas no estructuradas (noticias, reportes geopolíticos).
#
# 2. **Toma de decisiones con múltiples restricciones**: negociar simultáneamente con diferentes proveedores, transportistas, regulaciones y costos variables.
#
# 3. **Acción autónoma segura y verificable**: asegurar que las decisiones y acciones del agente sean confiables, auditables y en línea con políticas corporativas y regulatorias.
#
# 4. **Escalabilidad y adaptación**: operar con miles de SKU (productos) y múltiples regiones simultáneamente, aprendiendo continuamente de resultados previos.
#
# ---
#
# ¿Quieres que desarrollemos cómo diseñar arquitecturas agentic para atender esta problemática o que proponga un plan de pruebas y métricas para validar este tipo de agentes?
# ====================
# Gracias por compartir este problema tan interesante y complejo. Puedo ayudarte con ambos enfoques (arquitectura agentic o plan de pruebas y métricas), pero para empezar, propongo un diseño integral de arquitectura agentic para gestionarlo, que luego podríamos complementar con estrategias de validación.
#
# ---
#
# ## Propuesta de arquitectura agentic para gestión autónoma y proactiva de interrupciones en la cadena de suministro global
#
# ### 1. Componentes principales del sistema agentic
#
# #### a) **Agente de Monitoreo Multimodal (Sensores y Fuentes Externas)**
# - **Funciones**: Recolecta datos heterogéneos en tiempo real: sensores IoT (inventarios, estado transporte), APIs de tráfico y clima, scrapers y APIs para noticias, reportes regulatorios y geopolíticos, datos internos ERP/SCM.
# - **Tecnologías sugeridas**: Pipelines ETL, data lakes, NLP para análisis de textos no estructurados, feeds de datos en streaming (Kafka, Kinesis).
#
# #### b) **Agente de Detección y Análisis de Riesgos**
# - **Funciones**: Procesa flujos de datos para detectar anomalías y predecir riesgos con modelos ML/IA (análisis de series de tiempo, clustering, detección de eventos).
# - **Capacidades**: Predicciones de interrupciones, evaluación de severidad y probabilidad, generación de alertas tempranas.
# - **Ejemplos de modelos**: Redes neuronales, modelos bayesianos, modelos de NLP para análisis semántico de noticias.
#
# #### c) **Agente de Evaluación y Simulación de Impacto**
# - **Funciones**: Calcula impacto probable en costos, tiempos y disponibilidad para distintos escenarios de interrupción, usando simulaciones (por ejemplo, Monte Carlo) o frameworks basados en reglas.
# - Permite priorizar riesgos y oportunidades de mitigación.
#
# #### d) **Agente de Toma de Decisiones y Negociación Autónoma**
# - **Funciones**:
#   - Evalúa alternativas para minimizar impacto: cambios de proveedores, rutas, niveles de inventarios.
#   - Negocia condiciones en tiempo real con terceros mediante contratos inteligentes o APIs.
#   - Considera restricciones (contratos, regulaciones, costos).
# - Técnicas posibles: Optimización multiobjetivo, agentes de negociación automatizados, RL (Reinforcement Learning) para aprendizaje continuo.
#
# #### e) **Agente de Ejecución y Control**
# - **Funciones**: Implementa cambios aprobados en sistemas ERP, SCM, logísticos.
# - Asegura que las acciones cumplan políticas internas y normativas legales.
# - Genera logs y reportes para auditoría y trazabilidad.
#
# #### f) **Módulo de Supervisión Humana y Gobernanza**
# - Interfaz para supervisores humanos.
# - Alertas que necesitan confirmación.
# - Herramientas de explicación y transparencia (“explainability” en IA).
# - Revisión de acciones con riesgo o impacto mayor.
#
# ---
#
# ### 2. Flujo general del sistema
#
# 1. **Recolecta datos en streaming** →
# 2. **Detecta anomalías y riesgos** →
# 3. **Simula impactos de posibles interrupciones** →
# 4. **Propone planes de mitigación alternativos y negocia con actores externos** →
# 5. **Ejecuta cambios automáticamente o tras supervisión mínima** →
# 6. **Registra resultados y aprende para mejorar futuros ciclos**.
#
# ---
#
# ### 3. Recomendaciones técnicas y buenas prácticas
#
# - **Arquitectura en microservicios**, que permita escalabilidad y actualización independiente de cada agente.
# - **Uso de técnicas de IA explicable** para asegurar confianza y cumplimiento.
# - **Políticas de gobernanza AI** para evitar decisiones con riesgos inaceptables.
# - **Frameworks de orquestación** como Airflow o Kubeflow para gestión de pipelines.
# - **Seguridad y privacidad** en intercambio y almacenamiento de datos.
# - **Integración con blockchain o smart contracts** para trazabilidad y transparencia en negociaciones.
#
# ---
#
# ### 4. Aprendizaje y adaptación continua
#
# - Los agentes deben usar algoritmos de aprendizaje por refuerzo para ajustar estrategias negociadoras y optimizaciones.
# - Incorporar feedback humano y datos retrospectivos para afinar modelos predictivos.
# - Actualizar bases de conocimiento con cambios regulatorios y condiciones geopolíticas.
#
# ---
#
# Si quieres, puedo ayudarte ahora a definir el plan de pruebas, métricas clave para evaluar desempeño, robustez y seguridad del agente, o elaborar casos de uso concretos para probar la solución en entornos simulados o reales. ¿Qué prefieres?
